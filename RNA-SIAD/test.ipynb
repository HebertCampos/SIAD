# %%
import pandas as pd
# import seaborn as sns
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('df_mangabeiras.csv', sep=';')
# df = df.drop('area',axis=1)
print(df.head())
# Out:
#    area  condominio  preco
# 0    50         300  48000
# 1    55         220  50000
# 2    52         155  55000
# 3    58         300  58000
# 4    47         240  60000

# %%
sns.lmplot(x='area', y='preco', data=df)

# %%
sns.lmplot(x='condominio', y='preco', data=df)

# %%
x_df = df.drop('preco', axis=1)
x_df
# Out:
#      area  condominio
# 0      50         300
# 1      55         220
# 2      52         155
# 3      58         300
# 4      47         240
# ..    ...         ...
# 467   288        2000
# 468   278        1250
# 469   278        1450
# 470   278        1250
# 471   280        1800
#
# [472 rows x 2 columns]

# %%
y_df = df['preco']
y_df
# Out:
# 0        48000
# 1        50000
# 2        55000
# 3        58000
# 4        60000
#         ...
# 467    4100000
# 468    4200000
# 469    4500000
# 470    4900000
# 471    5200000
# Name: preco, Length: 472, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2)

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.7463947469905534

# %%
prediction_test = model.predict(X_test)
print(y_test, prediction_test)
print(np.mean(prediction_test - y_test))
# Out:
# 437    2500000
# 177     238000
# 79      135000
# 461    3500000
# 145     200000
#         ...
# 383    1550000
# 341    1280000
# 207     295000
# 446    2800000
# 434    2500000
# Name: preco, Length: 95, dtype: int64 [1697922.79163651  145020.74428192  213205.8528706  3165469.19695737
#   154391.06525738   63712.86088994  259625.31412117 1768117.38809646
#  1919943.95566151  165489.96073981 1440602.68903162  259625.31412117
#  1287083.56559747  140404.0032006  1304369.31066709  117341.92498227
#   360624.5554429    57021.83040027  175422.06843003 1784438.02573764
#  1253923.71796302 2211857.1755939    73947.46911888 1784438.02573764
#  1413946.62298654  201674.81376143 3632573.60322571 1840659.95159041
#  1378626.05721839 1483132.85764153  171972.11514091  125847.95870425
#  1460855.83367614  280094.53057906   46268.64981924  409867.38173075
#   -19755.74063574  238291.8104098    70144.60520357 2784174.20353776
#   220141.77808671 1697922.79163651  215798.71463104 2636453.04044059
#    57021.83040027  250773.5654978  1062195.86218637  286439.84616734
#  1457204.2400371  1726033.7545629   259193.17049443  216663.00188452
#  1044182.6686761   102058.43204527 1244553.39698756  -51460.69138888
#    81157.07196064 1970389.54836558 1375737.89064404  539323.30088026
#  1525684.6534397   164193.52985959  196625.92905338 1491775.73017634
#  1293565.71999858 1076024.45824206   96145.26008373  182502.02818377
#    41515.06992509 1109047.46706368  233891.14114186  163329.2426061
#   135650.42330646  513668.36090149 1377192.78752535  -10385.41966028
#  1970418.37127864  200810.52650795 1086712.83728601 2056904.7824667
#   105083.43743245  125847.95870425  512191.83683192   80854.57142193
#    46268.64981924 2030227.08923336  110132.32214051  264940.68073008
#  1560983.59201958  120799.0739962  2225570.56002503 1159493.05976774
#   228086.02509393 1452882.8037697  2138371.13185977]
# -27365.926657316097

# %%
np.mean(prediction_test - y_test)
# Out:
# -27365.926657316097

# %%
model.coef_, model.intercept_
# Out:
# (array([9370.32097546,  -43.21436267]), -339074.10224211996)

# %%
coeff1 = model.coef_[0]
coeff2 = model.coef_[1]
intercept = model.intercept_

# %%
x0 = 50
x1 = 210
# 160000

# %%
output = (x0*coeff1)+(x1*coeff2)+(intercept)
output
# Out:
# 120366.93036945537
